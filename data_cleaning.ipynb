# %% [markdown]
# # A Machine Learning Approach to Predicting Career Salary Estimates
# ## Data Cleaning

# %% [markdown]
# #### Necessary Libraries

# %%
import pandas as pd
import glob
import os

# %% [markdown]
# #### Ingesting our collected data by iterating through each file, and then creating a list of data frames

# %%
import pandas as pd
import glob


path = os.getcwd()
all_files = glob.glob(path + "/data_collection/data_files/*.csv")

dfs = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=0)
    dfs.append(df)

df = pd.concat(dfs, axis=0, ignore_index=True)

# %%
# Out:
#                                                Job Title  \
# 0                       IT Manager for Logistics Company
# 1                                            IT Director
# 2                                   Corporate IT Manager
# 3                                             IT Manager
# 4      IT Project Manager (Agile delivery experience ...
# ...                                                  ...
# 48923                         Programmer (Mathematician)
# 48924                            Data Scientist - Senior
# 48925  Senior Machine Learning Data Scientist - Telec...
# 48926                              Senior Data Scientist
# 48927                                     Data Scientist
#
#                               Salary Estimate  \
# 0       Employer Provided Salary:$80K - $100K
# 1       Employer Provided Salary:$80K - $100K
# 2        Employer Provided Salary:$85K - $95K
# 3        Employer Provided Salary:$75K - $85K
# 4      Employer Provided Salary:$120K - $150K
# ...                                       ...
# 48923             $73K - $91K (Employer est.)
# 48924             $73K - $91K (Employer est.)
# 48925             $73K - $91K (Employer est.)
# 48926             $73K - $91K (Employer est.)
# 48927             $73K - $91K (Employer est.)
#
#                                          Job Description  Rating  \
# 0      Job Summary:\nSupports all aspects of Company’...    -1.0
# 1      Seeking an experienced IT Director to oversee ...    -1.0
# 2      Noregon is looking for a Corporate IT Manager ...     3.6
# 3      Company: A small Entertainment Company located...    -1.0
# 4      *** Prefer candidates local to Washington DMV ...    -1.0
# ...                                                  ...     ...
# 48923  Programmer (Mathematician)\nVideo game\nGaming...     4.3
# 48924  Are you looking for opportunities to use cutti...     3.0
# 48925  Combine two of the fastest-growing fields on t...     3.7
# 48926  The Office Media Group (OMG) has a simple visi...     4.4
# 48927  Company Summary\nTaking care of our customers,...     4.0
#
#                      Company Name          Location                  Size  \
# 0        TradePort Logistics, LLC           Georgia               Unknown
# 1                    Confidential      Cranbury, NJ                    -1
# 2            Noregon Systems\n3.6    Greensboro, NC   51 to 200 Employees
# 3                    Confidential   Los Angeles, CA                    -1
# 4                Radiant Infotech   Catonsville, MD                    -1
# ...                           ...               ...                   ...
# 48923  Thompson Technologies\n4.3   Johns Creek, GA  201 to 500 Employees
# 48924             CVS Health\n3.0            Remote      10000+ Employees
# 48925     UnitedHealth Group\n3.7  Eden Prairie, MN      10000+ Employees
# 48926              Microsoft\n4.4       Redmond, WA      10000+ Employees
# 48927              Travelers\n4.0      Hartford, CT      10000+ Employees
#
#        Founded  Type of ownership                          Industry  \
# 0         -1.0   Company - Public                                -1
# 1         -1.0                 -1                                -1
# 2       1993.0  Company - Private      Computer Hardware & Software
# 3         -1.0                 -1                                -1
# 4         -1.0                 -1                                -1
# ...        ...                ...                               ...
# 48923   1995.0  Company - Private            Staffing & Outsourcing
# 48924   1963.0   Company - Public  Health Care Services & Hospitals
# 48925   1977.0   Company - Public  Health Care Services & Hospitals
# 48926   1975.0   Company - Public      Computer Hardware & Software
# 48927   1853.0   Company - Public                Insurance Carriers
#
#                        Sector                   Revenue
# 0                          -1  Unknown / Non-Applicable
# 1                          -1                        -1
# 2      Information Technology   $5 to $10 million (USD)
# 3                          -1                        -1
# 4                          -1                        -1
# ...                       ...                       ...
# 48923       Business Services  $25 to $50 million (USD)
# 48924             Health Care        $10+ billion (USD)
# 48925             Health Care        $10+ billion (USD)
# 48926  Information Technology        $10+ billion (USD)
# 48927               Insurance        $10+ billion (USD)
#
# [48928 rows x 12 columns]
